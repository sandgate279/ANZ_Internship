# %%
#Clean tye data set, remove outliers in columns balance and amount
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\sures\Desktop\ANZ synthesised transaction dataset (1).csv')
df.count()
# Out:
# status               12043
# card_present_flag     7717
# bpay_biller_code       885
# account              12043
# currency             12043
# long_lat             12043
# txn_description      12043
# merchant_id           7717
# merchant_code          883
# first_name           12043
# balance              12043
# date                 12043
# gender               12043
# age                  12043
# merchant_suburb       7717
# merchant_state        7717
# extraction           12043
# amount               12043
# transaction_id       12043
# country              12043
# customer_id          12043
# merchant_long_lat     7717
# movement             12043
# dtype: int64

# %%
df.isnull().sum()
# Out:
# status                   0
# card_present_flag     4326
# bpay_biller_code     11158
# account                  0
# currency                 0
# long_lat                 0
# txn_description          0
# merchant_id           4326
# merchant_code        11160
# first_name               0
# balance                  0
# date                     0
# gender                   0
# age                      0
# merchant_suburb       4326
# merchant_state        4326
# extraction               0
# amount                   0
# transaction_id           0
# country                  0
# customer_id              0
# merchant_long_lat     4326
# movement                 0
# dtype: int64

# %%
df.boxplot(by ='txn_description',grid='False',column =['amount'], color='red')

# %%
df.boxplot(by ='txn_description',grid='False',column =['balance'], color='red')

# %%
sorted(df)
# Out:
# ['account',
#  'age',
#  'amount',
#  'balance',
#  'bpay_biller_code',
#  'card_present_flag',
#  'country',
#  'currency',
#  'customer_id',
#  'date',
#  'extraction',
#  'first_name',
#  'gender',
#  'long_lat',
#  'merchant_code',
#  'merchant_id',
#  'merchant_long_lat',
#  'merchant_state',
#  'merchant_suburb',
#  'movement',
#  'status',
#  'transaction_id',
#  'txn_description']

# %%
#use inter quartile range to remove outliers in balance and amount
import numpy as np
q1, q3= np.percentile(df['balance'],[25,75])

# %%
iqr = q3 - q1

# %%
iqr
# Out:
# 9307.36

# %%
lower_bound = q1 -(1.5 * iqr) 
upper_bound = q3 +(1.5 * iqr)

# %%
lower_bound
# Out:
# -10802.455000000002

# %%
upper_bound
# Out:
# 26426.985

# %%
df.drop(df[df.balance > 17139.489999999998].index, inplace=True)

# %%
df.drop(df[df.balance < -6411.609999999999].index, inplace=True)

# %%
q1, q3= np.percentile(df['amount'],[25,75])

# %%
iqr = q3 - q1

# %%
iqr
# Out:
# 36.34

# %%
lower_bound = q1 -(1.5 * iqr) 
upper_bound = q3 +(1.5 * iqr)

# %%
lower_bound
# Out:
# -39.510000000000005

# %%
upper_bound
# Out:
# 105.85000000000001

# %%
df.drop(df[df.amount > 52.50375].index, inplace=True)

# %%
df.drop(df[df.amount < -13.80625].index, inplace=True)

# %%
df.isnull().sum()
# Out:
# status                  0
# card_present_flag    1641
# bpay_biller_code     7437
# account                 0
# currency                0
# long_lat                0
# txn_description         0
# merchant_id          1641
# merchant_code        7439
# first_name              0
# balance                 0
# date                    0
# gender                  0
# age                     0
# merchant_suburb      1641
# merchant_state       1641
# extraction              0
# amount                  0
# transaction_id          0
# country                 0
# customer_id             0
# merchant_long_lat    1641
# movement                0
# dtype: int64

# %%
df.count()
# Out:
# status               7439
# card_present_flag    5798
# bpay_biller_code        2
# account              7439
# currency             7439
# long_lat             7439
# txn_description      7439
# merchant_id          5798
# merchant_code           0
# first_name           7439
# balance              7439
# date                 7439
# gender               7439
# age                  7439
# merchant_suburb      5798
# merchant_state       5798
# extraction           7439
# amount               7439
# transaction_id       7439
# country              7439
# customer_id          7439
# merchant_long_lat    5798
# movement             7439
# dtype: int64

# %%
#write df to csv
df.to_csv(r'C:\Users\sures\Desktop\ANZ synthesised transaction datase(2).csv')
